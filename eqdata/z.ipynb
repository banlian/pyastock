# %%
from eqdata.z_helper import read_xlsx_codes

#
codes = read_xlsx_codes('short.xls')
print(codes)
codes = read_xlsx_codes('shortz.xls')
print(codes)
# Out:
# read csv success
# ['sz300415', 'sh600580', 'sh603713', 'sz123086', 'sz002055', 'sz000338', 'sz002475', 'sz002508', 'sz002232', 'sz301049', 'sz300860', 'sz301008', 'sz002101', 'sh603533', 'sz002790', 'sz300182', 'sh601700', 'sz002833', 'sz300291', 'sz000810', 'sz002884', 'sh603335', 'sz300663', 'sz300059', 'sz300691']
# read csv success
# ...

# %%
import pandas as pd
df = pd.read_csv('shortz.xls', encoding='gbk', sep='\t')

print(df)
# Out:
#           代码     名称     现价      涨幅     涨跌      涨速        总手     换手    量比  \
# 0   SZ002982   湘佳股份  45.18  +2.29%  +1.01  -0.57%   2621994  5.56%  1.94
# 1   SH688025    杰普特  72.90  -0.10%  -0.07  -0.51%   2060718  3.80%  0.96
# 2   SH600105   永鼎股份   5.85  -1.52%  -0.09  -0.17%  52137644  3.78%  0.69
# 3   SZ002080   中材科技  35.47  +2.51%  +0.87  +0.00%  20309784  1.21%  0.84
# 4   SH600233   圆通速递  17.33  +0.41%  +0.07  +0.06%  15902880  0.50%  0.70
# ..       ...    ...    ...     ...    ...     ...       ...    ...   ...
# 69  SZ300219   鸿利智汇  17.10  +1.30%  +0.22  -0.23%  16276600  2.59%  1.42
# 70  SH603043   广州酒家  22.87  -1.17%  -0.27  -0.04%   1736840  0.31%  0.76
# 71  SZ000423   东阿阿胶  45.33  -1.95%  -0.90  +0.29%  12907349  1.97%  1.25
# 72  SZ002614    奥佳华  11.92  -0.91%  -0.11  -0.08%   4256325  0.95%  0.78
# 73  SH603579   荣泰健康  30.14  -1.57%  -0.48  -0.13%    526600  0.38%  0.90
#
#           总金额  ...    所属行业   市净率 市盈率(pe)[20211223]     委比%   主力净量     振幅  \
# ...
